# %%
f= open("Day4","w")
f.write("IOT")
f.close()
print("done")
# Out:
# done

# %%
# pip install googlesearch-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from googlesearch import search

title = 'Free python course pdf'
data = search(title,num_results = 10)
all_data = []
for i in data:
    all_data.append(i+ "/n")

file =open(f"{title}.txt",'w')
file.writelines(all_data)
file.close()
print("done")
# Out:
# done

# %%
from googlesearch import search

title = 'Free java course pdf'
data = search(title,num_results = 10)
all_data = []
for i in data:
    all_data.append(i+ "/n")

file =open(f"{title}.txt",'x')
file.writelines(all_data)
file.close()
print("done")
# Out:
# done

# %%
from googlesearch import search

title = 'Free java course pdf'
data = search(title,num_results = 10)
all_data = []
for i in data:
    all_data.append(i+ "\n")

file =open(f"{title}.txt",'a')
file.write('-=-=-==-===-==-=-=--=-=-=-==-==-==-==-=-=-=-=-=''\n')
file.writelines(all_data)
file.close()
print("done")
# Out:
# done

# %%
f = open("new.txt","w+")

f.write("\nThis is Victus")
f.seek(0) #used to bring back cursor to 0 index 
print(f.read())
f.close()
# Out:
# This is Victus

# %%
f1= open('day_4.txt','r')
all_data = f1.read()

f2 = open('Day_4_copy.txt','w')
f2.write(all_data)

f1.close()
f2.close()

# %%
# Binary File Handling = bytes format

# %%
path = '''C:\\Users\\Govind Ahuja\\OneDrive\\Desktop\\ready-for-hulk-smash-5u-1920x1080.jpg'''
file = open(path,mode = 'rb')
data = file.read()
print("done")
# Out:
# done

# %%
type(data)
# Out:
# bytes

# %%
print(data)
# Out:
# b'\xff\xd8\xff\xdb\x00C\x00\x02\x01\x01\x01\x01\x01\x02\x01\x01\x01\x02\x02\x02\x02\x02\x04\x03\x02\x02\x02\x02\x05\x04\x04\x03\x04\x06\x05\x06\x06\x06\x05\x06\x06\x06\x07\t\x08\x06\x07\t\x07\x06\x06\x08\x0b\x08\t\n\n\n\n\n\x06\x08\x0b\x0c\x0b\n\x0c\t\n\n\n\xff\xdb\x00C\x01\x02\x02\x02\x02\x02\x02\x05\x03\x03\x05\n\x07\x06\x07\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xff\xc0\x00\x11\x08\x048\x07\x80\x03\x01\x11\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\x83\x84\x85\x86\x87\x88\x89\x8a\x92\x93\x94\x95\x96\x97\x98\x99\x9a\xa2\xa3\xa4\xa5\xa6\xa7\xa8\xa9\xaa\xb2\xb3\xb
# ...

# %%
f= open('image.jpg','wb')
f.write(data)
f.close()
print("done")
# Out:
# done

# %%
url = '''https://th.bing.com/th/id/OIP.AevggYcQFhHnvNIrjVUbVAHaEK?w=267&h=200&c=12&rs=1&p=0&o=6&pid=23.1'''
import requests as r
image_data = r.get(url).content


f = open('download_image.jpg','wb')
f.write(image_data)
f.close()

from IPython import display
display.Image('download_image.jpg')

# %%
url = '''https://fastly.picsum.photos/id/695/3840/2160.jpg?hmac=9jqMXY4G7e0gB5YcqdexAn3NpX9nzh5XV1Q9WO8WKsQ'''
import requests as r 
no = 10
for i  in range(no):
    img_data = r.get(url).content 
    f = open (f'image_(i).jpg','wb')
    f.write(img_data)
    f.close()

from IPython import display as d
display(d.Image(f'image_(i).jpg',width =500,height = 500))

# %%
url = "https://instapdf.in/download-free/?pdfid=3983"

import requests as r
with open(r'C:\Users\Govind Ahuja\OneDrive\Desktop\Data Science IITM\permission.pdf','wb') as file:
    file.write(r.get(url).content)

print("Done")
# Out:
# Done
